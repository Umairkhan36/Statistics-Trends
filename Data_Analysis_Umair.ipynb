# %% [markdown]
# **Student Name: Umair khan**
#
# **Student ID: 23036693**

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('BangorTelco_Customers.csv')

# Display basic statistics of the dataset
print("Basic statistics of the dataset:")
print(df.describe())

# Function to create a histogram/bar chart/pie chart
def plot_histogram(data):
    # Example: Plot a histogram of 'INCOME' column
    plt.figure(figsize=(8, 6))
    sns.histplot(data['INCOME'], bins=20, kde=True)
    plt.title('Distribution of Income')
    plt.xlabel('Income')
    plt.ylabel('Frequency')
    plt.show()

# Function to create a line/scatter graph
# Function to create a scatter plot
def plot_scatter(data):
    # Example: Plot a scatter plot between 'HANDSET_PRICE' and 'INCOME'
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='HANDSET_PRICE', y='INCOME', data=data)
    plt.title('Handset Price vs Income')
    plt.xlabel('Handset Price')
    plt.ylabel('Income')
    plt.show()

# Function to create a confusion matrix/heatmap/corner/box/violin plot
def plot_heatmap(data):
    # Example: Plot a heatmap showing correlations between numeric columns
    plt.figure(figsize=(10, 8))
    sns.heatmap(data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title('Correlation Heatmap')
    plt.show()
# Function to create a scatter plot with trend lines for 'INCOME' and 'HOUSE' prices
def plot_income_house_scatter_trend(data):
    plt.figure(figsize=(10, 6))

    # Scatter plot for 'INCOME' and 'HOUSE'
    sns.scatterplot(x='INCOME', y='HOUSE', data=data, color='red', label='Data Points')

    # Fitting linear regression lines to the data
    reg_income = LinearRegression().fit(data[['INCOME']], data['HOUSE'])
    reg_house = LinearRegression().fit(data[['HOUSE']], data['INCOME'])

    # Plotting trend lines
    plt.plot(data['INCOME'], reg_income.predict(data[['INCOME']]), linestyle='dashed', color='blue', label='Income Trend Line')
    plt.plot(reg_house.predict(data[['HOUSE']]), data['HOUSE'], linestyle='dashed', color='green', label='House Price Trend Line')

    plt.title('Relationship between Income and House Price')
    plt.xlabel('Income')
    plt.ylabel('House Price')
    plt.legend()
    plt.show()


# Function to create a readable chart for summary statistics
def plot_summary_statistics(data):
    # Calculate summary statistics
    summary_stats = data.describe().transpose()

    # Plotting
    plt.figure(figsize=(10, 6))
    summary_stats.plot(kind='bar', alpha=0.75)
    plt.title('Summary Statistics of Numeric Variables')
    plt.xlabel('Variables')
    plt.ylabel('Values')
    plt.xticks(rotation=45)
    plt.legend(loc='upper right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Call the functions to generate plots
plot_histogram(df)
plot_scatter(df)
plot_heatmap(df)
plot_income_house_scatter_trend(df)
plot_summary_statistics(df)
# Out:
# Basic statistics of the dataset:
#               INCOME       OVERAGE      LEFTOVER          HOUSE  \
# count   20000.000000  20000.000000  20000.000000   20000.000000
# mean    80281.447750     85.979550     23.898650  493155.264250
# std     41680.586319     85.992324     26.816645  252407.884692
# min     20007.000000     -2.000000      0.000000  150002.000000
# 25%     42217.000000      0.000000      0.000000  263714.250000
# 50%     75366.500000     59.000000     14.000000  452259.500000
# 75%    115881.750000    179.000000     41.000000  702378.000000
# max    159983.000000    335.000000     89.000000  999996.000000
#
#        HANDSET_PRICE  OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION
# count   20000.000000                 20000.000000           20000.000000
# mean      389.615100                     8.000700               6.002250
# std       213.820682                     8.925418               4.402558
# ...
